# %%
import pandas as pd
import json
import time
from datetime import datetime
import os

# Read the CSV file from the same folder
csv_path = "/Workspace/Users/nikhithareddye08@gmail.com/finguard_project/fraud_watchlist_file_generator/fraud_watchlist.csv"
df = pd.read_csv(csv_path)

# Ensure entity_id is always a string for JSON serialization
df['entity_id'] = df['entity_id'].astype(str)

# Target volume path
output_path = "/Volumes/finguard/source/fraud_watchlist/source_data/"

# Ensure the output directory exists
dbutils.fs.mkdirs(output_path)

# Check for existing files and find the latest watchlist_id
latest_watchlist_id = None
try:
    existing_files = dbutils.fs.ls(output_path)
    if existing_files:
        print(f"Found {len(existing_files)} existing files in {output_path}")
        print("Scanning for latest watchlist_id...")
        
        max_id_num = 0
        for file_info in existing_files:
            if file_info.name.endswith('.json'):
                try:
                    # Read the JSON file
                    content = dbutils.fs.head(file_info.path, 10000)
                    data = json.loads(content)
                    watchlist_id = data.get('watchlist_id', '')
                    # Extract numeric part from watchlist_id (e.g., "WL000001" -> 1)
                    if watchlist_id.startswith('WL'):
                        id_num = int(watchlist_id[2:])
                        if id_num > max_id_num:
                            max_id_num = id_num
                            latest_watchlist_id = watchlist_id
                except Exception as e:
                    continue
        
        if latest_watchlist_id:
            print(f"Latest watchlist_id found: {latest_watchlist_id} (numeric: {max_id_num})")
            # Filter dataframe to start from next record using numeric comparison
            # Extract numeric part from dataframe's watchlist_id for comparison
            df['_id_num'] = df['watchlist_id'].str[2:].astype(int)
            df = df[df['_id_num'] > max_id_num].drop(columns=['_id_num']).reset_index(drop=True)
            print(f"Resuming from next record. {len(df)} rows remaining to process.\n")
        else:
            print("No valid watchlist_id found in existing files. Starting from beginning.\n")
    else:
        print("No existing files found. Starting from beginning.\n")
except Exception as e:
    print(f"Could not read existing files: {e}")
    print("Starting from beginning.\n")

if len(df) == 0:
    print("All records have already been processed!")
else:
    print(f"Starting to process {len(df)} rows from fraud_watchlist.csv")
    print(f"Writing JSON files to: {output_path}")
    print("\n" + "="*60 + "\n")

    # Process each row one at a time
    for index, row in df.iterrows():
        # Convert row to dictionary (column name as key, column value as value)
        row_dict = row.to_dict()
        
        # Ensure entity_id is a string in the dictionary
        row_dict['entity_id'] = str(row_dict['entity_id'])
        
        # Print the entire row being written
        print(f"Entire row being written: {row_dict}")
        
        # Create a unique filename with timestamp
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")
        filename = f"fraud_watchlist_{timestamp}_{index}.json"
        file_path = f"{output_path}/{filename}"
        
        # Write JSON to file using dbutils.fs (required for Unity Catalog volumes)
        # Single-line JSON format
        json_content = json.dumps(row_dict)
        dbutils.fs.put(file_path, json_content, overwrite=True)
        
        print(f"Row {index + 1}/{len(df)}: Written {filename}")
        print(f"  Watchlist ID: {row_dict.get('watchlist_id')}")
        
        # Wait 5 seconds before processing next row (except for the last one)
        if index < len(df) - 1:
            print(f"  Waiting 5 seconds...\n")
            time.sleep(5)
    
    print("\n" + "="*60)
    print(f"\nCompleted! Generated {len(df)} JSON files in {output_path}")
# Out:
# Found 5 existing files in /Volumes/finguard/source/fraud_watchlist/source_data/
# Scanning for latest watchlist_id...
# No valid watchlist_id found in existing files. Starting from beginning.
#
# Starting to process 341 rows from fraud_watchlist.csv
# Writing JSON files to: /Volumes/finguard/source/fraud_watchlist/source_data/
#
# ============================================================
#
# Entire row being written: {'watchlist_id': 'wl000001', 'watch_type': 'CARD', 'entity_id': '5008514036965665', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'PHISHING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:00:00', 'reported_by': 'SOC', 'reported_source': 'Manual', 'country': 'India', 'city': 'Hyderabad'}
# Wrote 365 bytes.
# Row 1/341: Written fraud_watchlist_20260715_151145_694705_0.json
#   Watchlist ID: wl000001
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000002', 'watch_type': 'CARD', 'entity_id': '4413337312552355', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'BLACKLISTED_MERCHANT', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:01:00', 'reported_by': 'SOC', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Pune'}
# Wrote 379 bytes.
# Row 2/341: Written fraud_watchlist_20260715_151151_048215_1.json
#   Watchlist ID: wl000002
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000003', 'watch_type': 'CARD', 'entity_id': '5329839542961842', 'risk_level': 'low', 'action': 'ADD', 'reason_code': 'TEST_TRANSACTION', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:02:00', 'reported_by': 'AML Team', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Delhi'}
# Wrote 380 bytes.
# Row 3/341: Written fraud_watchlist_20260715_151156_397701_2.json
#   Watchlist ID: wl000003
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000004', 'watch_type': 'CARD', 'entity_id': '4717327980595032', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'TEST_TRANSACTION', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:04:00', 'reported_by': 'AML Team', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Chennai'}
# Wrote 383 bytes.
# Row 4/341: Written fraud_watchlist_20260715_151201_868558_3.json
#   Watchlist ID: wl000004
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000005', 'watch_type': 'CARD', 'entity_id': '4260650191792026', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'ACCOUNT_TAKEOVER', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:07:00', 'reported_by': 'Customer Care', 'reported_source': 'CRM', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 384 bytes.
# Row 5/341: Written fraud_watchlist_20260715_151207_272652_4.json
#   Watchlist ID: wl000005
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000006', 'watch_type': 'CARD', 'entity_id': '4009109391119268', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'TEST_TRANSACTION', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:12:00', 'reported_by': 'SOC', 'reported_source': 'Manual', 'country': 'India', 'city': 'Mumbai'}
# Wrote 370 bytes.
# Row 6/341: Written fraud_watchlist_20260715_151212_746216_5.json
#   Watchlist ID: wl000006
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000007', 'watch_type': 'CARD', 'entity_id': '5953506373118040', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'SUSPICIOUS_ACTIVITY', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:28:00', 'reported_by': 'AML Team', 'reported_source': 'AML', 'country': 'India', 'city': 'Chennai'}
# Wrote 378 bytes.
# Row 7/341: Written fraud_watchlist_20260715_151218_080513_6.json
#   Watchlist ID: wl000007
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000008', 'watch_type': 'CARD', 'entity_id': '4519832731585146', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'ACCOUNT_TAKEOVER', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:31:00', 'reported_by': 'AML Team', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 389 bytes.
# Row 8/341: Written fraud_watchlist_20260715_151223_547818_7.json
#   Watchlist ID: wl000008
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000009', 'watch_type': 'CARD', 'entity_id': '4910622723626693', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'VELOCITY_FRAUD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:32:00', 'reported_by': 'AML Team', 'reported_source': 'Manual', 'country': 'India', 'city': 'Chennai'}
# Wrote 374 bytes.
# Row 9/341: Written fraud_watchlist_20260715_151228_905623_8.json
#   Watchlist ID: wl000009
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000010', 'watch_type': 'CARD', 'entity_id': '5229812099576576', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'PHISHING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:33:00', 'reported_by': 'Customer Care', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Mumbai'}
# Wrote 379 bytes.
# Row 10/341: Written fraud_watchlist_20260715_151234_379699_9.json
#   Watchlist ID: wl000010
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000011', 'watch_type': 'CARD', 'entity_id': '5310720113798442', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'LOST_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:35:00', 'reported_by': 'SOC', 'reported_source': 'AML', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 363 bytes.
# Row 11/341: Written fraud_watchlist_20260715_151239_747008_10.json
#   Watchlist ID: wl000011
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000012', 'watch_type': 'CARD', 'entity_id': '5456232858842477', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'MONEY_LAUNDERING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:37:00', 'reported_by': 'Fraud Team', 'reported_source': 'CRM', 'country': 'India', 'city': 'Mumbai'}
# Wrote 374 bytes.
# Row 12/341: Written fraud_watchlist_20260715_151245_201646_11.json
#   Watchlist ID: wl000012
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000013', 'watch_type': 'CARD', 'entity_id': '5791776334272032', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'LOST_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:41:00', 'reported_by': 'Customer Care', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Mumbai'}
# Wrote 382 bytes.
# Row 13/341: Written fraud_watchlist_20260715_151250_586017_12.json
#   Watchlist ID: wl000013
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000014', 'watch_type': 'CARD', 'entity_id': '5863144170646255', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'STOLEN_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:43:00', 'reported_by': 'Fraud Team', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Pune'}
# Wrote 377 bytes.
# Row 14/341: Written fraud_watchlist_20260715_151256_035024_13.json
#   Watchlist ID: wl000014
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000015', 'watch_type': 'CARD', 'entity_id': '5729293143866328', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'STOLEN_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:49:00', 'reported_by': 'SOC', 'reported_source': 'AML', 'country': 'India', 'city': 'Delhi'}
# Wrote 361 bytes.
# Row 15/341: Written fraud_watchlist_20260715_151301_414972_14.json
#   Watchlist ID: wl000015
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000016', 'watch_type': 'CARD', 'entity_id': '4552457871584155', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'SUSPICIOUS_ACTIVITY', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:53:00', 'reported_by': 'SOC', 'reported_source': 'Manual', 'country': 'India', 'city': 'Mumbai'}
# Wrote 373 bytes.
# Row 16/341: Written fraud_watchlist_20260715_151306_886136_15.json
#   Watchlist ID: wl000016
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000017', 'watch_type': 'CARD', 'entity_id': '4645257775478124', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'TEST_TRANSACTION', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:55:00', 'reported_by': 'Fraud Team', 'reported_source': 'CRM', 'country': 'India', 'city': 'Chennai'}
# Wrote 379 bytes.
# Row 17/341: Written fraud_watchlist_20260715_151312_253807_16.json
#   Watchlist ID: wl000017
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000018', 'watch_type': 'CARD', 'entity_id': '5487632909279140', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'PHISHING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:56:00', 'reported_by': 'AML Team', 'reported_source': 'Manual', 'country': 'India', 'city': 'Delhi'}
# Wrote 368 bytes.
# Row 18/341: Written fraud_watchlist_20260715_151317_707654_17.json
#   Watchlist ID: wl000018
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000019', 'watch_type': 'CARD', 'entity_id': '5004010414596428', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'COMPROMISED_DEVICE', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:58:00', 'reported_by': 'Customer Care', 'reported_source': 'CRM', 'country': 'India', 'city': 'Delhi'}
# Wrote 378 bytes.
# Row 19/341: Written fraud_watchlist_20260715_151323_085537_18.json
#   Watchlist ID: wl000019
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000020', 'watch_type': 'CARD', 'entity_id': '5999404389836409', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'STOLEN_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 09:59:00', 'reported_by': 'SOC', 'reported_source': 'AML', 'country': 'India', 'city': 'Mumbai'}
# Wrote 364 bytes.
# Row 20/341: Written fraud_watchlist_20260715_151328_578080_19.json
#   Watchlist ID: wl000020
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000021', 'watch_type': 'CARD', 'entity_id': '5806533315377954', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'ACCOUNT_TAKEOVER', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 10:02:00', 'reported_by': 'AML Team', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Pune'}
# Wrote 384 bytes.
# Row 21/341: Written fraud_watchlist_20260715_151333_942689_20.json
#   Watchlist ID: wl000021
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000022', 'watch_type': 'CARD', 'entity_id': '4391065180170461', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'LOST_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 10:03:00', 'reported_by': 'AML Team', 'reported_source': 'AML', 'country': 'India', 'city': 'Delhi'}
# Wrote 364 bytes.
# Row 22/341: Written fraud_watchlist_20260715_151339_640399_21.json
#   Watchlist ID: wl000022
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000023', 'watch_type': 'CARD', 'entity_id': '4269312163761826', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'VELOCITY_FRAUD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 10:04:00', 'reported_by': 'Customer Care', 'reported_source': 'CRM', 'country': 'India', 'city': 'Pune'}
# Wrote 373 bytes.
# Row 23/341: Written fraud_watchlist_20260715_151345_015906_22.json
#   Watchlist ID: wl000023
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000024', 'watch_type': 'CARD', 'entity_id': '5953766014448563', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'VELOCITY_FRAUD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 10:05:00', 'reported_by': 'AML Team', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 385 bytes.
# Row 24/341: Written fraud_watchlist_20260715_151350_443158_23.json
#   Watchlist ID: wl000024
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000025', 'watch_type': 'CARD', 'entity_id': '4254257306624818', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'BLACKLISTED_MERCHANT', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 10:06:00', 'reported_by': 'AML Team', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Mumbai'}
# Wrote 388 bytes.
# Row 25/341: Written fraud_watchlist_20260715_151355_805697_24.json
#   Watchlist ID: wl000025
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000026', 'watch_type': 'CARD', 'entity_id': '5047264261212036', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'STOLEN_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 10:07:00', 'reported_by': 'SOC', 'reported_source': 'AML', 'country': 'India', 'city': 'Mumbai'}
# Wrote 366 bytes.
# Row 26/341: Written fraud_watchlist_20260715_151401_250747_25.json
#   Watchlist ID: wl000026
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000027', 'watch_type': 'CARD', 'entity_id': '5940539103717053', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'ACCOUNT_TAKEOVER', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 10:12:00', 'reported_by': 'AML Team', 'reported_source': 'AML', 'country': 'India', 'city': 'Pune'}
# Wrote 372 bytes.
# Row 27/341: Written fraud_watchlist_20260715_151406_589042_26.json
#   Watchlist ID: wl000027
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000028', 'watch_type': 'CARD', 'entity_id': '4856728727601539', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'PHISHING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 10:21:00', 'reported_by': 'SOC', 'reported_source': 'CRM', 'country': 'India', 'city': 'Delhi'}
# Wrote 358 bytes.
# Row 28/341: Written fraud_watchlist_20260715_151412_080871_27.json
#   Watchlist ID: wl000028
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000029', 'watch_type': 'CARD', 'entity_id': '5443270185106798', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'VELOCITY_FRAUD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 10:24:00', 'reported_by': 'AML Team', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Chennai'}
# Wrote 383 bytes.
# Row 29/341: Written fraud_watchlist_20260715_151417_422578_28.json
#   Watchlist ID: wl000029
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000030', 'watch_type': 'CARD', 'entity_id': '4659152017774904', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'PHISHING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 10:27:00', 'reported_by': 'Fraud Team', 'reported_source': 'Manual', 'country': 'India', 'city': 'Hyderabad'}
# Wrote 372 bytes.
# Row 30/341: Written fraud_watchlist_20260715_151422_868638_29.json
#   Watchlist ID: wl000030
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000031', 'watch_type': 'CARD', 'entity_id': '5095493059660186', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'TEST_TRANSACTION', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 10:30:00', 'reported_by': 'AML Team', 'reported_source': 'Manual', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 380 bytes.
# Row 31/341: Written fraud_watchlist_20260715_151428_197839_30.json
#   Watchlist ID: wl000031
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000032', 'watch_type': 'CARD', 'entity_id': '5696325953278771', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'LOST_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 10:34:00', 'reported_by': 'SOC', 'reported_source': 'CRM', 'country': 'India', 'city': 'Chennai'}
# Wrote 363 bytes.
# Row 32/341: Written fraud_watchlist_20260715_151433_762779_31.json
#   Watchlist ID: wl000032
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000033', 'watch_type': 'CARD', 'entity_id': '4138759271256639', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'MONEY_LAUNDERING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 10:36:00', 'reported_by': 'SOC', 'reported_source': 'Manual', 'country': 'India', 'city': 'Mumbai'}
# Wrote 374 bytes.
# Row 33/341: Written fraud_watchlist_20260715_151439_128747_32.json
#   Watchlist ID: wl000033
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000034', 'watch_type': 'CARD', 'entity_id': '5311091939284565', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'MONEY_LAUNDERING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 10:40:00', 'reported_by': 'Customer Care', 'reported_source': 'Manual', 'country': 'India', 'city': 'Pune'}
# Wrote 382 bytes.
# Row 34/341: Written fraud_watchlist_20260715_151444_563253_33.json
#   Watchlist ID: wl000034
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000035', 'watch_type': 'CARD', 'entity_id': '4355610399529709', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'LOST_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 10:48:00', 'reported_by': 'Fraud Team', 'reported_source': 'CRM', 'country': 'India', 'city': 'Pune'}
# Wrote 367 bytes.
# Row 35/341: Written fraud_watchlist_20260715_151449_903764_34.json
#   Watchlist ID: wl000035
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000036', 'watch_type': 'CARD', 'entity_id': '5570836821444885', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'TEST_TRANSACTION', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 10:51:00', 'reported_by': 'SOC', 'reported_source': 'Manual', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 373 bytes.
# Row 36/341: Written fraud_watchlist_20260715_151455_354845_35.json
#   Watchlist ID: wl000036
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000037', 'watch_type': 'CARD', 'entity_id': '5204618723460132', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'MONEY_LAUNDERING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 10:53:00', 'reported_by': 'AML Team', 'reported_source': 'AML', 'country': 'India', 'city': 'Delhi'}
# Wrote 373 bytes.
# Row 37/341: Written fraud_watchlist_20260715_151500_719687_36.json
#   Watchlist ID: wl000037
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000038', 'watch_type': 'CARD', 'entity_id': '5524914168601347', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'COMPROMISED_DEVICE', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 10:54:00', 'reported_by': 'Customer Care', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Mumbai'}
# Wrote 391 bytes.
# Row 38/341: Written fraud_watchlist_20260715_151506_324048_37.json
#   Watchlist ID: wl000038
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000039', 'watch_type': 'CARD', 'entity_id': '5729293143866328', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'ACCOUNT_TAKEOVER', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 10:55:00', 'reported_by': 'AML Team', 'reported_source': 'Manual', 'country': 'India', 'city': 'Pune'}
# Wrote 373 bytes.
# Row 39/341: Written fraud_watchlist_20260715_151511_670696_38.json
#   Watchlist ID: wl000039
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000040', 'watch_type': 'CARD', 'entity_id': '4627136111554268', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'STOLEN_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 10:59:00', 'reported_by': 'Customer Care', 'reported_source': 'CRM', 'country': 'India', 'city': 'Pune'}
# Wrote 370 bytes.
# Row 40/341: Written fraud_watchlist_20260715_151517_252557_39.json
#   Watchlist ID: wl000040
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000041', 'watch_type': 'CARD', 'entity_id': '5430391171822783', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'SUSPICIOUS_ACTIVITY', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:01:00', 'reported_by': 'Customer Care', 'reported_source': 'AML', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 383 bytes.
# Row 41/341: Written fraud_watchlist_20260715_151522_598674_40.json
#   Watchlist ID: wl000041
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000042', 'watch_type': 'CARD', 'entity_id': '4845218230768105', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'COMPROMISED_DEVICE', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:02:00', 'reported_by': 'Customer Care', 'reported_source': 'Manual', 'country': 'India', 'city': 'Delhi'}
# Wrote 383 bytes.
# Row 42/341: Written fraud_watchlist_20260715_151528_037932_41.json
#   Watchlist ID: wl000042
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000043', 'watch_type': 'CARD', 'entity_id': '5916202232883777', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'BLACKLISTED_MERCHANT', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:03:00', 'reported_by': 'Fraud Team', 'reported_source': 'AML', 'country': 'India', 'city': 'Pune'}
# Wrote 380 bytes.
# Row 43/341: Written fraud_watchlist_20260715_151533_379913_42.json
#   Watchlist ID: wl000043
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000044', 'watch_type': 'CARD', 'entity_id': '4894346810548514', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'TEST_TRANSACTION', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:09:00', 'reported_by': 'SOC', 'reported_source': 'AML', 'country': 'India', 'city': 'Delhi'}
# Wrote 366 bytes.
# Row 44/341: Written fraud_watchlist_20260715_151539_119128_43.json
#   Watchlist ID: wl000044
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000045', 'watch_type': 'CARD', 'entity_id': '4562137213865898', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'ACCOUNT_TAKEOVER', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:11:00', 'reported_by': 'AML Team', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Hyderabad'}
# Wrote 387 bytes.
# Row 45/341: Written fraud_watchlist_20260715_151544_569107_44.json
#   Watchlist ID: wl000045
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000046', 'watch_type': 'CARD', 'entity_id': '5445189520284571', 'risk_level': 'low', 'action': 'ADD', 'reason_code': 'TEST_TRANSACTION', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:12:00', 'reported_by': 'Fraud Team', 'reported_source': 'CRM', 'country': 'India', 'city': 'Pune'}
# Wrote 371 bytes.
# Row 46/341: Written fraud_watchlist_20260715_151550_056769_45.json
#   Watchlist ID: wl000046
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000047', 'watch_type': 'CARD', 'entity_id': '5033445056658836', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'PHISHING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:13:00', 'reported_by': 'Customer Care', 'reported_source': 'AML', 'country': 'India', 'city': 'Hyderabad'}
# Wrote 374 bytes.
# Row 47/341: Written fraud_watchlist_20260715_151555_483838_46.json
#   Watchlist ID: wl000047
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000048', 'watch_type': 'CARD', 'entity_id': '4826068887189818', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'COMPROMISED_DEVICE', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:20:00', 'reported_by': 'Customer Care', 'reported_source': 'Manual', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 385 bytes.
# Row 48/341: Written fraud_watchlist_20260715_151601_246635_47.json
#   Watchlist ID: wl000048
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000049', 'watch_type': 'CARD', 'entity_id': '5459910229014760', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'STOLEN_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:21:00', 'reported_by': 'Fraud Team', 'reported_source': 'CRM', 'country': 'India', 'city': 'Hyderabad'}
# Wrote 372 bytes.
# Row 49/341: Written fraud_watchlist_20260715_151606_647584_48.json
#   Watchlist ID: wl000049
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000050', 'watch_type': 'CARD', 'entity_id': '4272405593429679', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'COMPROMISED_DEVICE', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:25:00', 'reported_by': 'Fraud Team', 'reported_source': 'AML', 'country': 'India', 'city': 'Delhi'}
# Wrote 377 bytes.
# Row 50/341: Written fraud_watchlist_20260715_151612_111154_49.json
#   Watchlist ID: wl000050
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000051', 'watch_type': 'CARD', 'entity_id': '5618495931034137', 'risk_level': 'low', 'action': 'ADD', 'reason_code': 'ACCOUNT_TAKEOVER', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:27:00', 'reported_by': 'Fraud Team', 'reported_source': 'AML', 'country': 'India', 'city': 'Delhi'}
# Wrote 372 bytes.
# Row 51/341: Written fraud_watchlist_20260715_151617_466797_50.json
#   Watchlist ID: wl000051
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000052', 'watch_type': 'CARD', 'entity_id': '4900696801867740', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'LOST_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:29:00', 'reported_by': 'Fraud Team', 'reported_source': 'CRM', 'country': 'India', 'city': 'Delhi'}
# Wrote 366 bytes.
# Row 52/341: Written fraud_watchlist_20260715_151622_891160_51.json
#   Watchlist ID: wl000052
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000053', 'watch_type': 'CARD', 'entity_id': '5972154064176922', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'VELOCITY_FRAUD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:30:00', 'reported_by': 'SOC', 'reported_source': 'AML', 'country': 'India', 'city': 'Mumbai'}
# Wrote 365 bytes.
# Row 53/341: Written fraud_watchlist_20260715_151628_229184_52.json
#   Watchlist ID: wl000053
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000054', 'watch_type': 'CARD', 'entity_id': '5352904228421023', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'COMPROMISED_DEVICE', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:41:00', 'reported_by': 'Fraud Team', 'reported_source': 'CRM', 'country': 'India', 'city': 'Chennai'}
# Wrote 379 bytes.
# Row 54/341: Written fraud_watchlist_20260715_151634_114479_53.json
#   Watchlist ID: wl000054
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000055', 'watch_type': 'CARD', 'entity_id': '5051553234159593', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'PHISHING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:44:00', 'reported_by': 'Fraud Team', 'reported_source': 'Manual', 'country': 'India', 'city': 'Delhi'}
# Wrote 372 bytes.
# Row 55/341: Written fraud_watchlist_20260715_151639_468004_54.json
#   Watchlist ID: wl000055
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000056', 'watch_type': 'CARD', 'entity_id': '4045069176799351', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'PHISHING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:46:00', 'reported_by': 'Fraud Team', 'reported_source': 'Manual', 'country': 'India', 'city': 'Hyderabad'}
# Wrote 372 bytes.
# Row 56/341: Written fraud_watchlist_20260715_151644_916947_55.json
#   Watchlist ID: wl000056
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000057', 'watch_type': 'CARD', 'entity_id': '4054119986798070', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'TEST_TRANSACTION', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:50:00', 'reported_by': 'SOC', 'reported_source': 'AML', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 372 bytes.
# Row 57/341: Written fraud_watchlist_20260715_151650_273250_56.json
#   Watchlist ID: wl000057
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000058', 'watch_type': 'CARD', 'entity_id': '4926932657327598', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'ACCOUNT_TAKEOVER', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:51:00', 'reported_by': 'AML Team', 'reported_source': 'CRM', 'country': 'India', 'city': 'Pune'}
# Wrote 374 bytes.
# Row 58/341: Written fraud_watchlist_20260715_151655_719539_57.json
#   Watchlist ID: wl000058
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000059', 'watch_type': 'CARD', 'entity_id': '5076502412095797', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'ACCOUNT_TAKEOVER', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:54:00', 'reported_by': 'Customer Care', 'reported_source': 'AML', 'country': 'India', 'city': 'Hyderabad'}
# Wrote 384 bytes.
# Row 59/341: Written fraud_watchlist_20260715_151701_062553_58.json
#   Watchlist ID: wl000059
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000060', 'watch_type': 'CARD', 'entity_id': '4574817006661554', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'TEST_TRANSACTION', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:55:00', 'reported_by': 'AML Team', 'reported_source': 'CRM', 'country': 'India', 'city': 'Pune'}
# Wrote 370 bytes.
# Row 60/341: Written fraud_watchlist_20260715_151706_517167_59.json
#   Watchlist ID: wl000060
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000061', 'watch_type': 'CARD', 'entity_id': '4193592361337600', 'risk_level': 'low', 'action': 'ADD', 'reason_code': 'BLACKLISTED_MERCHANT', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 11:56:00', 'reported_by': 'Fraud Team', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Mumbai'}
# Wrote 387 bytes.
# Row 61/341: Written fraud_watchlist_20260715_151711_865559_60.json
#   Watchlist ID: wl000061
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000062', 'watch_type': 'CARD', 'entity_id': '5947174648877192', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'STOLEN_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 12:01:00', 'reported_by': 'Customer Care', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Delhi'}
# Wrote 381 bytes.
# Row 62/341: Written fraud_watchlist_20260715_151717_631691_61.json
#   Watchlist ID: wl000062
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000063', 'watch_type': 'CARD', 'entity_id': '4975147439742925', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'TEST_TRANSACTION', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 12:03:00', 'reported_by': 'Customer Care', 'reported_source': 'CRM', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 384 bytes.
# Row 63/341: Written fraud_watchlist_20260715_151722_999621_62.json
#   Watchlist ID: wl000063
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000064', 'watch_type': 'CARD', 'entity_id': '4990139837354036', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'MONEY_LAUNDERING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 12:08:00', 'reported_by': 'SOC', 'reported_source': 'Manual', 'country': 'India', 'city': 'Chennai'}
# Wrote 371 bytes.
# Row 64/341: Written fraud_watchlist_20260715_151728_540983_63.json
#   Watchlist ID: wl000064
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000065', 'watch_type': 'CARD', 'entity_id': '4009109391119268', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'BLACKLISTED_MERCHANT', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 12:09:00', 'reported_by': 'AML Team', 'reported_source': 'CRM', 'country': 'India', 'city': 'Hyderabad'}
# Wrote 381 bytes.
# Row 65/341: Written fraud_watchlist_20260715_151733_844159_64.json
#   Watchlist ID: wl000065
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000066', 'watch_type': 'CARD', 'entity_id': '5407663493396508', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'PHISHING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 12:10:00', 'reported_by': 'Fraud Team', 'reported_source': 'Manual', 'country': 'India', 'city': 'Mumbai'}
# Wrote 373 bytes.
# Row 66/341: Written fraud_watchlist_20260715_151739_567872_65.json
#   Watchlist ID: wl000066
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000067', 'watch_type': 'CARD', 'entity_id': '5097921583503442', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'ACCOUNT_TAKEOVER', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 12:11:00', 'reported_by': 'Customer Care', 'reported_source': 'AML', 'country': 'India', 'city': 'Hyderabad'}
# Wrote 382 bytes.
# Row 67/341: Written fraud_watchlist_20260715_151744_913650_66.json
#   Watchlist ID: wl000067
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000068', 'watch_type': 'CARD', 'entity_id': '5113989868180977', 'risk_level': 'low', 'action': 'ADD', 'reason_code': 'PHISHING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 12:25:00', 'reported_by': 'AML Team', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Hyderabad'}
# Wrote 376 bytes.
# Row 68/341: Written fraud_watchlist_20260715_151750_355647_67.json
#   Watchlist ID: wl000068
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000069', 'watch_type': 'CARD', 'entity_id': '4715534820128404', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'VELOCITY_FRAUD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 12:31:00', 'reported_by': 'AML Team', 'reported_source': 'CRM', 'country': 'India', 'city': 'Chennai'}
# Wrote 371 bytes.
# Row 69/341: Written fraud_watchlist_20260715_151755_696981_68.json
#   Watchlist ID: wl000069
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000070', 'watch_type': 'CARD', 'entity_id': '5010651333872621', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'LOST_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 12:35:00', 'reported_by': 'Fraud Team', 'reported_source': 'AML', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 370 bytes.
# Row 70/341: Written fraud_watchlist_20260715_151801_125927_69.json
#   Watchlist ID: wl000070
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000071', 'watch_type': 'CARD', 'entity_id': '5133595616420590', 'risk_level': 'low', 'action': 'ADD', 'reason_code': 'SUSPICIOUS_ACTIVITY', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 12:36:00', 'reported_by': 'AML Team', 'reported_source': 'AML', 'country': 'India', 'city': 'Hyderabad'}
# Wrote 377 bytes.
# Row 71/341: Written fraud_watchlist_20260715_151806_435426_70.json
#   Watchlist ID: wl000071
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000072', 'watch_type': 'CARD', 'entity_id': '5951003076205456', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'PHISHING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 12:40:00', 'reported_by': 'Customer Care', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 386 bytes.
# Row 72/341: Written fraud_watchlist_20260715_151811_913365_71.json
#   Watchlist ID: wl000072
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000073', 'watch_type': 'CARD', 'entity_id': '5104584743621307', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'BLACKLISTED_MERCHANT', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 12:41:00', 'reported_by': 'Customer Care', 'reported_source': 'CRM', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 388 bytes.
# Row 73/341: Written fraud_watchlist_20260715_151817_253955_72.json
#   Watchlist ID: wl000073
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000074', 'watch_type': 'CARD', 'entity_id': '5134074517133952', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'STOLEN_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 12:45:00', 'reported_by': 'SOC', 'reported_source': 'AML', 'country': 'India', 'city': 'Pune'}
# Wrote 364 bytes.
# Row 74/341: Written fraud_watchlist_20260715_151822_700122_73.json
#   Watchlist ID: wl000074
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000075', 'watch_type': 'CARD', 'entity_id': '5339449530067761', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'COMPROMISED_DEVICE', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 12:50:00', 'reported_by': 'Customer Care', 'reported_source': 'Manual', 'country': 'India', 'city': 'Chennai'}
# Wrote 383 bytes.
# Row 75/341: Written fraud_watchlist_20260715_151828_044203_74.json
#   Watchlist ID: wl000075
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000076', 'watch_type': 'CARD', 'entity_id': '4422319646300407', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'SUSPICIOUS_ACTIVITY', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 12:53:00', 'reported_by': 'AML Team', 'reported_source': 'AML', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 378 bytes.
# Row 76/341: Written fraud_watchlist_20260715_151833_479443_75.json
#   Watchlist ID: wl000076
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000077', 'watch_type': 'CARD', 'entity_id': '5117536170617131', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'SUSPICIOUS_ACTIVITY', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 12:59:00', 'reported_by': 'AML Team', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Delhi'}
# Wrote 388 bytes.
# Row 77/341: Written fraud_watchlist_20260715_151838_814193_76.json
#   Watchlist ID: wl000077
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000078', 'watch_type': 'CARD', 'entity_id': '5133595616420590', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'STOLEN_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:01:00', 'reported_by': 'Fraud Team', 'reported_source': 'CRM', 'country': 'India', 'city': 'Mumbai'}
# Wrote 373 bytes.
# Row 78/341: Written fraud_watchlist_20260715_151844_309118_77.json
#   Watchlist ID: wl000078
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000079', 'watch_type': 'CARD', 'entity_id': '4606853615305158', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'SUSPICIOUS_ACTIVITY', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:02:00', 'reported_by': 'Customer Care', 'reported_source': 'Manual', 'country': 'India', 'city': 'Mumbai'}
# Wrote 387 bytes.
# Row 79/341: Written fraud_watchlist_20260715_151849_649000_78.json
#   Watchlist ID: wl000079
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000080', 'watch_type': 'CARD', 'entity_id': '4847609441283330', 'risk_level': 'low', 'action': 'ADD', 'reason_code': 'STOLEN_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:08:00', 'reported_by': 'Fraud Team', 'reported_source': 'AML', 'country': 'India', 'city': 'Delhi'}
# Wrote 367 bytes.
# Row 80/341: Written fraud_watchlist_20260715_151855_086260_79.json
#   Watchlist ID: wl000080
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000081', 'watch_type': 'CARD', 'entity_id': '5067323182971684', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'STOLEN_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:09:00', 'reported_by': 'SOC', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Chennai'}
# Wrote 375 bytes.
# Row 81/341: Written fraud_watchlist_20260715_151900_446966_80.json
#   Watchlist ID: wl000081
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000082', 'watch_type': 'CARD', 'entity_id': '4468135926648695', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'PHISHING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:10:00', 'reported_by': 'Fraud Team', 'reported_source': 'Manual', 'country': 'India', 'city': 'Mumbai'}
# Wrote 373 bytes.
# Row 82/341: Written fraud_watchlist_20260715_151905_855679_81.json
#   Watchlist ID: wl000082
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000083', 'watch_type': 'CARD', 'entity_id': '5275208854749296', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'COMPROMISED_DEVICE', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:11:00', 'reported_by': 'SOC', 'reported_source': 'CRM', 'country': 'India', 'city': 'Chennai'}
# Wrote 372 bytes.
# Row 83/341: Written fraud_watchlist_20260715_151911_202881_82.json
#   Watchlist ID: wl000083
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000084', 'watch_type': 'CARD', 'entity_id': '4569040983665522', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'TEST_TRANSACTION', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:13:00', 'reported_by': 'AML Team', 'reported_source': 'CRM', 'country': 'India', 'city': 'Chennai'}
# Wrote 377 bytes.
# Row 84/341: Written fraud_watchlist_20260715_151916_644306_83.json
#   Watchlist ID: wl000084
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000085', 'watch_type': 'CARD', 'entity_id': '5110475412126781', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'ACCOUNT_TAKEOVER', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:15:00', 'reported_by': 'Customer Care', 'reported_source': 'CRM', 'country': 'India', 'city': 'Chennai'}
# Wrote 378 bytes.
# Row 85/341: Written fraud_watchlist_20260715_151922_026730_84.json
#   Watchlist ID: wl000085
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000086', 'watch_type': 'CARD', 'entity_id': '4106987205061492', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'VELOCITY_FRAUD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:18:00', 'reported_by': 'AML Team', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Mumbai'}
# Wrote 382 bytes.
# Row 86/341: Written fraud_watchlist_20260715_151927_613864_85.json
#   Watchlist ID: wl000086
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000087', 'watch_type': 'CARD', 'entity_id': '4280598262045050', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'SUSPICIOUS_ACTIVITY', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:20:00', 'reported_by': 'Customer Care', 'reported_source': 'Manual', 'country': 'India', 'city': 'Pune'}
# Wrote 385 bytes.
# Row 87/341: Written fraud_watchlist_20260715_151932_979390_86.json
#   Watchlist ID: wl000087
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000088', 'watch_type': 'CARD', 'entity_id': '4204339718956908', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'TEST_TRANSACTION', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:22:00', 'reported_by': 'Customer Care', 'reported_source': 'Manual', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 385 bytes.
# Row 88/341: Written fraud_watchlist_20260715_151938_410334_87.json
#   Watchlist ID: wl000088
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000089', 'watch_type': 'CARD', 'entity_id': '5729949387430273', 'risk_level': 'low', 'action': 'ADD', 'reason_code': 'MONEY_LAUNDERING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:24:00', 'reported_by': 'AML Team', 'reported_source': 'Manual', 'country': 'India', 'city': 'Delhi'}
# Wrote 373 bytes.
# Row 89/341: Written fraud_watchlist_20260715_151943_750611_88.json
#   Watchlist ID: wl000089
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000090', 'watch_type': 'CARD', 'entity_id': '5806533315377954', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'ACCOUNT_TAKEOVER', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:33:00', 'reported_by': 'Fraud Team', 'reported_source': 'CRM', 'country': 'India', 'city': 'Mumbai'}
# Wrote 374 bytes.
# Row 90/341: Written fraud_watchlist_20260715_151949_291562_89.json
#   Watchlist ID: wl000090
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000091', 'watch_type': 'CARD', 'entity_id': '5758997571130550', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'BLACKLISTED_MERCHANT', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:36:00', 'reported_by': 'AML Team', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 389 bytes.
# Row 91/341: Written fraud_watchlist_20260715_151954_605482_90.json
#   Watchlist ID: wl000091
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000092', 'watch_type': 'CARD', 'entity_id': '5275208854749296', 'risk_level': 'low', 'action': 'ADD', 'reason_code': 'STOLEN_CARD', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:37:00', 'reported_by': 'Fraud Team', 'reported_source': 'AML', 'country': 'India', 'city': 'Hyderabad'}
# Wrote 371 bytes.
# Row 92/341: Written fraud_watchlist_20260715_152000_211142_91.json
#   Watchlist ID: wl000092
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000093', 'watch_type': 'CARD', 'entity_id': '4464844941163182', 'risk_level': 'low', 'action': 'ADD', 'reason_code': 'COMPROMISED_DEVICE', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:44:00', 'reported_by': 'Customer Care', 'reported_source': 'CRM', 'country': 'India', 'city': 'Mumbai'}
# Wrote 378 bytes.
# Row 93/341: Written fraud_watchlist_20260715_152005_583698_92.json
#   Watchlist ID: wl000093
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000094', 'watch_type': 'CARD', 'entity_id': '5025743263039753', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'ACCOUNT_TAKEOVER', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:47:00', 'reported_by': 'AML Team', 'reported_source': 'AML', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 379 bytes.
# Row 94/341: Written fraud_watchlist_20260715_152011_025973_93.json
#   Watchlist ID: wl000094
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000095', 'watch_type': 'CARD', 'entity_id': '4003296334727277', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'BLACKLISTED_MERCHANT', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:48:00', 'reported_by': 'AML Team', 'reported_source': 'Manual', 'country': 'India', 'city': 'Mumbai'}
# Wrote 379 bytes.
# Row 95/341: Written fraud_watchlist_20260715_152016_377414_94.json
#   Watchlist ID: wl000095
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000096', 'watch_type': 'CARD', 'entity_id': '5229231067245309', 'risk_level': 'high', 'action': 'ADD', 'reason_code': 'SUSPICIOUS_ACTIVITY', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:50:00', 'reported_by': 'Customer Care', 'reported_source': 'Manual', 'country': 'India', 'city': 'Hyderabad'}
# Wrote 386 bytes.
# Row 96/341: Written fraud_watchlist_20260715_152021_893742_95.json
#   Watchlist ID: wl000096
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000097', 'watch_type': 'CARD', 'entity_id': '4905150267551253', 'risk_level': 'medium', 'action': 'ADD', 'reason_code': 'MONEY_LAUNDERING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:51:00', 'reported_by': 'AML Team', 'reported_source': 'External Feed', 'country': 'India', 'city': 'Bengaluru'}
# Wrote 387 bytes.
# Row 97/341: Written fraud_watchlist_20260715_152027_245173_96.json
#   Watchlist ID: wl000097
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000098', 'watch_type': 'CARD', 'entity_id': '5747226408572164', 'risk_level': 'critical', 'action': 'ADD', 'reason_code': 'BLACKLISTED_MERCHANT', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:54:00', 'reported_by': 'AML Team', 'reported_source': 'CRM', 'country': 'India', 'city': 'Mumbai'}
# Wrote 380 bytes.
# Row 98/341: Written fraud_watchlist_20260715_152032_793389_97.json
#   Watchlist ID: wl000098
#   Waiting 5 seconds...
#
# Entire row being written: {'watchlist_id': 'wl000099', 'watch_type': 'CARD', 'entity_id': '5181845184894762', 'risk_level': 'low', 'action': 'ADD', 'reason_code': 'MONEY_LAUNDERING', 'reason_description': 'Auto-generated fraud watchlist entry', 'status': 'ACTIVE', 'effective_from': '18-Jun-2026 13:55:00', 'reported_by': 'AML Team', 'reported_source': 'AML', 'country': 'India', 'city': 'Pune'}
# Wrote 369 bytes.
# Row 99/341: Written fraud_watchlist_20260715_152038_129311_98.json
#   Watchlist ID: wl000099
#   Waiting 5 seconds...
